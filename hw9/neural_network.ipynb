# %% [markdown]
# # Neural Network Example
#
# Xây dựng neural network với hai tầng ẩn (hidden layer). Các trọng số và mối liên hệ giữa các tầng ẩn được thiết lập và cài đặt bằng việc sử dụng API của thư viện PyTorch

# %% [markdown]
# ## Neural Network Overview
#
# <img src="http://cs231n.github.io/assets/nn1/neural_net2.jpeg" alt="nn" style="width: 400px;"/>
#
# ## MNIST Dataset Overview

# %%
from __future__ import absolute_import, division, print_function

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
import numpy as np

# %%
# Chuẩn bị dữ liệu
from tensorflow.keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Chuyển đổi sang định dạng float32.
x_train, x_test = np.array(x_train, np.float32), np.array(x_test, np.float32)
# Chuẩn hóa ảnh từ from [0, 255] to [0, 1].
x_train, x_test = x_train / 255, x_test / 255
x_train, x_test, y_train, y_test = torch.from_numpy(x_train), torch.from_numpy(x_test), torch.from_numpy(y_train).type(torch.LongTensor), torch.from_numpy(y_test).type(torch.LongTensor)

# %%
# MNIST dataset parameters.
num_classes = 10 # total classes (0-9 digits).
num_features = 784 # data features (img shape: 28*28).

# Network parameters.
n_hidden_1 = 128 # 1st layer number of neurons.
n_hidden_2 = 256 # 2nd layer number of neurons.

# %%
batch_size = 16

# %%
trainloader = []
for (i,j) in zip(x_train, y_train):
    trainloader.append([i,j])
trainloader = torch.utils.data.DataLoader(trainloader, shuffle=True, batch_size=batch_size)

testloader = []
for (i,j) in zip(x_test, y_test):
    testloader.append([i,j])
testloader = torch.utils.data.DataLoader(testloader, shuffle=True, batch_size = batch_size)

# %% [markdown]
# ## Hiển thị một vài ví dụ

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

dataiter = iter(trainloader)
images, labels = next(dataiter) # dataiter.next() -> error
images = images.numpy()

# hiển thị dữ liệu theo từng batch và nhãn tương ứng
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(batch_size):
    ax = fig.add_subplot(2, batch_size//2, idx+1, xticks=[], yticks=[]) #batch_size -> int
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title(str(labels[idx].item()))

# %%
import torch.nn as nn
import torch.nn.functional as F

## định nghĩa mạng
class MLPModel(nn.Module):
    def __init__(self):
        super(MLPModel, self).__init__()
        self.fc1 = nn.Linear(num_features, n_hidden_1)
        # linear layer (n_hidden -> hidden_2)
        self.fc2 = nn.Linear(n_hidden_1, n_hidden_2)

    def forward(self, x):
        # chuyển từ định dạng ma trận thành vector
        x = x.view(-1, 28 * 28)
        # add hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return x

# initialize the NN
model = MLPModel()
print(model)
# Out:
# MLPModel(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
# )

# %%
import torch.optim as optim
# trong hàm loss cross entropy đã áp dụng hàm soft max cho vector đầu ra
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
def accuracy():
    correct = 0
    total = 0
    # model.eval()
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            # calculate outputs by running images through the network
            outputs = model(images)
            # the class with the highest energy is what we choose as prediction
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    return correct/total

# %%
losses = []
for epoch in range(10):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
        loss = criterion(outputs, labels) #-> hàm mất mát
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
    losses.append(running_loss)
    # if epoch % 10 == 1:
    print('Iteration: %d, accuracy: %.3f' %(epoch + 1, accuracy()))

print('Finished Training')
# Out:
# Iteration: 1, accuracy: 0.902
# Iteration: 2, accuracy: 0.917
# Iteration: 3, accuracy: 0.928
# Iteration: 4, accuracy: 0.938
# Iteration: 5, accuracy: 0.943
# Iteration: 6, accuracy: 0.948
# Iteration: 7, accuracy: 0.952
# Iteration: 8, accuracy: 0.955
# Iteration: 9, accuracy: 0.957
# Iteration: 10, accuracy: 0.961
# Finished Training

# %%
# Biểu đồ biểu diễn độ biến thiên của hàm mất mát qua các vòng lặp
plt.plot([i for i in range(len(losses))], losses, label='Loss line')
# plt.plot(X, np.array(W * X + b), label='Fitted line')
plt.legend()
plt.show()

# %% [markdown]
# ## Bài tập
#
# *   Tiến hành huấn luyện mô hình với số lượng epoch lần lượt là 50, 100, 150.Rút ra nhận xét.

# %%
losses = []
for epoch in range(50):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
        loss = criterion(outputs, labels) #-> hàm mất mát
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
    losses.append(running_loss)
    if epoch % 5 == 4:
        print('Iteration: %d, accuracy: %.3f' %(epoch + 1, accuracy()))
# Out:
# Iteration: 5, accuracy: 0.881
# Iteration: 10, accuracy: 0.881
# Iteration: 15, accuracy: 0.881
# Iteration: 20, accuracy: 0.882
# Iteration: 25, accuracy: 0.882
# Iteration: 30, accuracy: 0.881
# Iteration: 35, accuracy: 0.883
# Iteration: 40, accuracy: 0.882
# Iteration: 45, accuracy: 0.882
# Iteration: 50, accuracy: 0.882

# %% [markdown]
# *   Hiển thị một số kết quả

# %%
# obtain one batch of test images
dataiter = iter(testloader)
images, labels = next(dataiter)

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)
# prep images for display
images = images.numpy()

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(batch_size):
    ax = fig.add_subplot(2, batch_size//2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title("{} ({})".format(str(preds[idx].item()), str(labels[idx].item())),
                 color=("green" if preds[idx]==labels[idx] else "red"))

# %% [markdown]
# ## Bài tập
#
# *   Thiết lập thêm 3 mạng nơ ron với số tầng ẩn lần lượt là 3,5 (số lượng nơ ron của các tầng tùy ý). Với mỗi mạng mới được sinh ra, áp dụng learning-rate lần lượt bằng 0.1, 0,05, 0.001 để huấn luyện. Huấn luyện qua khoảng 100 epoch.
# *   Chia tập train hiện có thành 2 phần. **85%** dữ liệu làm tập **train**, **15%** còn lại làm tập **dev**. Huấn luyện các mô hình tạo ra ở bước trên với tập **train** mới, sau đó kiểm thử trên tập **dev**.
# * Dùng các model kiểm thử trên tập **test**. So sánh model cho kết quả tốt nhất khi kiểm thử trên 2 tập này và rút ra nhận xét về vai trò của tập **dev**

# %%
#3 tầng ẩn
n_hidden_3 = 100
class MLPModel2(MLPModel):
    def __init__(self):
        super(MLPModel2, self).__init__()
        self.fc3 = nn.Linear(n_hidden_2, n_hidden_3)
    def forward(self, x):
        # chuyển từ định dạng ma trận thành vector
        x = x.view(-1, 28 * 28)
        # add hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        return x
model = MLPModel2()
# print(model)

#Chia train set
from sklearn.model_selection import train_test_split
x_train2, x_val, y_train2, y_val = train_test_split(x_train, y_train, test_size=0.15)
validloader = []
for (i,j) in zip(x_val, y_val):
    validloader.append([i,j])
validloader = torch.utils.data.DataLoader(validloader, shuffle=True, batch_size=batch_size)

trainloader = []
for (i,j) in zip(x_train2, y_train2):
    trainloader.append([i,j])
trainloader = torch.utils.data.DataLoader(trainloader, shuffle=True, batch_size=batch_size)

testloader = []
for (i,j) in zip(x_test, y_test):
    testloader.append([i,j])
testloader = torch.utils.data.DataLoader(testloader, shuffle=True, batch_size = batch_size)


#Hàm accuracy
def accuracy2():
    correct = 0
    total = 0
    # model.eval()
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            # calculate outputs by running images through the network
            outputs = model(images)
            # the class with the highest energy is what we choose as prediction
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    return correct/total
criterion = nn.CrossEntropyLoss()
lr = [0.1, 0.05, 0.001]
for i in lr:
    print(f"At learning rate {i}:")
    optimizer = optim.SGD(model.parameters(), lr = i)
    losses = []
    for epoch in range(50):  # loop over the dataset multiple times
        model.train()
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = model(inputs)
            loss = criterion(outputs, labels) #-> hàm mất mát
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
        losses.append(running_loss)
        model.eval()
        accuracy2()
        if epoch % 5 == 4:
            print('Iteration: %d, accuracy: %.3f' %(epoch + 1, accuracy2()))
# Out:
# At learning rate 0.1:
# Iteration: 5, accuracy: 0.977
# Iteration: 10, accuracy: 0.980
# Iteration: 15, accuracy: 0.979
# Iteration: 20, accuracy: 0.985
# Iteration: 25, accuracy: 0.985
# Iteration: 30, accuracy: 0.985
# Iteration: 35, accuracy: 0.985
# Iteration: 40, accuracy: 0.985
# Iteration: 45, accuracy: 0.985
# Iteration: 50, accuracy: 0.984
# At learning rate 0.05:
# Iteration: 5, accuracy: 0.985
# Iteration: 10, accuracy: 0.984
# Iteration: 15, accuracy: 0.985
# Iteration: 20, accuracy: 0.985
# Iteration: 25, accuracy: 0.984
# Iteration: 30, accuracy: 0.985
# Iteration: 35, accuracy: 0.985
# Iteration: 40, accuracy: 0.984
# Iteration: 45, accuracy: 0.984
# Iteration: 50, accuracy: 0.984
# At learning rate 0.001:
# Iteration: 5, accuracy: 0.984
# Iteration: 10, accuracy: 0.984
# Iteration: 15, accuracy: 0.984
# Iteration: 20, accuracy: 0.984
# Iteration: 25, accuracy: 0.984
# Iteration: 30, accuracy: 0.984
# Iteration: 35, accuracy: 0.984
# Iteration: 40, accuracy: 0.984
# Iteration: 45, accuracy: 0.984
# Iteration: 50, accuracy: 0.984
